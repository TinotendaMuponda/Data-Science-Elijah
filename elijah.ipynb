# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

#imported dataset
df = pd.read_csv('DATASET.csv')
pd.set_option('display.max_columns', None)
#printing first 5
data.head()

# df = pd.DataFrame(data,columns=['customer_id', 'mrating',  'PD'])

# df.plot()

# df.plot(x="PD", y="customer_id", kind = "hist")

# df.plot.barh(stacked=True);

df.plot(x="customer_id", y="mrating", kind = "scatter", title = "Analysis")

# plt.plot(df["customer_id"], df["mrating"])

df.describe()


# df.plot.scatter()
# Out:
# C:\Users\s145\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (1,2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         customer_id   intodefault       mrating            PD
# count  41679.000000  41679.000000  41679.000000  41681.000000
# mean    1247.592049      0.218407     16.776746      0.093648
# std      725.133831      0.413170      3.692638      0.101505
# min        1.000000      0.000000     10.000000      0.001000
# 25%      619.000000      0.000000     14.000000      0.016000
# 50%     1240.000000      0.000000     17.000000      0.060000
# 75%     1877.000000      0.000000     20.000000      0.160000
# max     2501.000000      1.000000     25.000000      0.450000

# %%
import pandas as pd

scottish_hills = {'Ben Nevis': (1345, 56.79685, -5.003508),
                  'Ben Macdui': (1309, 57.070453, -3.668262),
                  'Braeriach': (1296, 57.078628, -3.728024),
                  'Cairn Toul': (1291, 57.054611, -3.71042),
                  'Sgòr an Lochain Uaine': (1258, 57.057999, -3.725416)}

dataframe = pd.DataFrame(scottish_hills)
print(dataframe)
# Out:
#      Ben Nevis   Ben Macdui    Braeriach   Cairn Toul  Sgòr an Lochain Uaine
# 0  1345.000000  1309.000000  1296.000000  1291.000000            1258.000000
# 1    56.796850    57.070453    57.078628    57.054611              57.057999
# 2    -5.003508    -3.668262    -3.728024    -3.710420              -3.725416

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     41679 non-null  float64
#  1   reporting_date  41679 non-null  object
#  2   default_moment  9918 non-null   object
#  3   intodefault     41679 non-null  float64
#  4   mrating         41679 non-null  float64
#  5   PD              41681 non-null  float64
# dtypes: float64(4), object(2)
# memory usage: 48.0+ MB

# %%
#Exploratory Analysis

sns.countplot(df['PD'])
# Out:
# C:\Users\s145\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='PD', ylabel='count'>

# %%
sns.countplot(df['intodefault']).set(title='Analysis of Defaults')
# Out:
# C:\Users\s145\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Analysis of Defaults')]

# %%
#Numeric Analysis
#The Graph is positively skewed

sns.distplot(df['PD'])
# Out:
# C:\Users\s145\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PD', ylabel='Density'>

# %%
df['PD'] = np.log(df['PD'])
sns.distplot(df['PD'])
# Out:
# C:\Users\s145\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PD', ylabel='Density'>

# %%
# %load_ext watermark

# %watermark --iversions
# Out:
# pandas    : 1.1.3
# seaborn   : 0.11.0
# numpy     : 1.19.2
# matplotlib: 3.3.2
